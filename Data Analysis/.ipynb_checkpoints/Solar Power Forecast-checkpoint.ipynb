# %%
# import neccessary library
import tensorflow as tf
import statsmodels.api as sm 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # 1. Preprocessing Data
# # 1.1 Import and Cleansing Data

# %%
def read_cleanse_excel(file_name, file_date):
    data = pd.read_excel(file_name)

    # extract date from first column, row 5:end
    date = data.iloc[5:,0].apply(lambda x : pd.to_datetime(file_date + ' ' + str(x)))
    # extract power_kW from 16th column
    power_kW = data.iloc[5:, 16]/1e3

    # create new_frame that is exist only date and power_kW
    new_frame = pd.DataFrame([date,  power_kW])
    new_frame = new_frame.T
    new_frame.columns = ['datetime', 'power_kW']
    new_frame['datetime'] = pd.to_datetime(new_frame['datetime'])
    new_frame = new_frame.set_index(['datetime'])

    # check minor missing data
    if new_frame.shape[0] > 275 and new_frame.shape[0] < 288:
        for i in range(new_frame.shape[0]):
            # identify index of missing data
            dif = (new_frame.index[i+1] - new_frame.index[i]).seconds/60  
            if dif > 5:
                num_mis = round(dif/5 - 1) # amount of missing data

                resolution = (new_frame.iloc[i+1,0] - new_frame.iloc[i,0])/(num_mis+1)

                add_frame = pd.DataFrame({}, columns = ['datetime', 'power_kW'])
                start_new_frame = new_frame.index[i]
                start_new_value = new_frame.iloc[i,0]
                
                for k in range(int(num_mis)):
                    # add delta step 300 sec and value to add_frame
                    start_new_frame = start_new_frame + pd.Timedelta('300 s')
                    start_new_value = start_new_value + resolution
                    
                    add_time = start_new_frame
                    add_value = start_new_value
                    add_frame = pd.concat([add_frame,
                                           pd.DataFrame({'datetime':add_time, 'power_kW':add_value},
                                                        index=[0])])
                # set index to datetime
                add_frame = add_frame.set_index(['datetime'])

                # add add_frame to existing frame and sort by index
                new_frame = pd.concat([new_frame, add_frame])
                new_frame.sort_index(inplace = True)          
        return new_frame, new_frame.shape[0]
    
    # return data immediatly if this day have complete data
    elif new_frame.shape[0] == 288:
        return new_frame, new_frame.shape[0]
    
    # too much value missing return None
    else:
        return None, new_frame.shape[0]

# %%
## Retreive all data in the year

date_start = '2013-01-01'
date_temp = date_start
file_name = 'SolarRadiance/' + date_temp + '.xls'

num_stat = []
data, num = read_cleanse_excel(file_name, file_date = date_temp)
num_stat.append(num)

# Loop and import pv data
for i in range(364):
    date_temp = str(pd.to_datetime(date_temp) + pd.Timedelta('1 d'))[0:10]
    print(date_temp)
               
    file_name = 'SolarRadiance/' + date_temp + '.xls'
    data_day, num = read_cleanse_excel(file_name, file_date = date_temp) 
    
    # if data_day is none, it means that too much values are vanish in this day, skip it
    if data_day is not None:
        data = pd.concat([data, data_day])
    num_stat.append(num)
# Out:
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# 2013-03-18
# 2013-03-19
# 2013-03-20
# 2013-03-21
# 2013-03-22
# 2013-03-23
# 2013-03-24
# 2013-03-25
# 2013-03-26
# 2013-03-27
# 2013-03-28
# 2013-03-29
# 2013-03-30
# 2013-03-31
# 2013-04-01
# 2013-04-02
# 2013-04-03
# 2013-04-04
# 2013-04-05
# 2013-04-06
# 2013-04-07
# 2013-04-08
# 2013-04-09
# 2013-04-10
# 2013-04-11
# 2013-04-12
# 2013-04-13
# 2013-04-14
# 2013-04-15
# 2013-04-16
# 2013-04-17
# 2013-04-18
# 2013-04-19
# 2013-04-20
# 2013-04-21
# 2013-04-22
# 2013-04-23
# 2013-04-24
# 2013-04-25
# 2013-04-26
# 2013-04-27
# 2013-04-28
# 2013-04-29
# 2013-04-30
# 2013-05-01
# 2013-05-02
# 2013-05-03
# 2013-05-04
# 2013-05-05
# 2013-05-06
# 2013-05-07
# 2013-05-08
# 2013-05-09
# 2013-05-10
# 2013-05-11
# 2013-05-12
# 2013-05-13
# 2013-05-14
# 2013-05-15
# 2013-05-16
# 2013-05-17
# 2013-05-18
# 2013-05-19
# 2013-05-20
# 2013-05-21
# 2013-05-22
# 2013-05-23
# 2013-05-24
# 2013-05-25
# 2013-05-26
# 2013-05-27
# 2013-05-28
# 2013-05-29
# 2013-05-30
# 2013-05-31
# 2013-06-01
# 2013-06-02
# 2013-06-03
# 2013-06-04
# 2013-06-05
# 2013-06-06
# 2013-06-07
# 2013-06-08
# 2013-06-09
# 2013-06-10
# 2013-06-11
# 2013-06-12
# 2013-06-13
# 2013-06-14
# 2013-06-15
# 2013-06-16
# 2013-06-17
# 2013-06-18
# 2013-06-19
# 2013-06-20
# 2013-06-21
# 2013-06-22
# 2013-06-23
# 2013-06-24
# 2013-06-25
# 2013-06-26
# 2013-06-27
# 2013-06-28
# 2013-06-29
# 2013-06-30
# 2013-07-01
# 2013-07-02
# 2013-07-03
# 2013-07-04
# 2013-07-05
# 2013-07-06
# 2013-07-07
# 2013-07-08
# 2013-07-09
# 2013-07-10
# 2013-07-11
# 2013-07-12
# 2013-07-13
# 2013-07-14
# 2013-07-15
# 2013-07-16
# 2013-07-17
# 2013-07-18
# 2013-07-19
# 2013-07-20
# 2013-07-21
# 2013-07-22
# 2013-07-23
# 2013-07-24
# 2013-07-25
# 2013-07-26
# 2013-07-27
# 2013-07-28
# 2013-07-29
# 2013-07-30
# 2013-07-31
# 2013-08-01
# 2013-08-02
# 2013-08-03
# 2013-08-04
# 2013-08-05
# 2013-08-06
# 2013-08-07
# 2013-08-08
# 2013-08-09
# 2013-08-10
# 2013-08-11
# 2013-08-12
# 2013-08-13
# 2013-08-14
# 2013-08-15
# 2013-08-16
# 2013-08-17
# 2013-08-18
# 2013-08-19
# 2013-08-20
# 2013-08-21
# 2013-08-22
# 2013-08-23
# 2013-08-24
# 2013-08-25
# 2013-08-26
# 2013-08-27
# 2013-08-28
# 2013-08-29
# 2013-08-30
# 2013-08-31
# 2013-09-01
# 2013-09-02
# 2013-09-03
# 2013-09-04
# 2013-09-05
# 2013-09-06
# 2013-09-07
# 2013-09-08
# 2013-09-09
# 2013-09-10
# 2013-09-11
# 2013-09-12
# 2013-09-13
# 2013-09-14
# 2013-09-15
# 2013-09-16
# 2013-09-17
# 2013-09-18
# 2013-09-19
# 2013-09-20
# 2013-09-21
# 2013-09-22
# 2013-09-23
# 2013-09-24
# 2013-09-25
# 2013-09-26
# 2013-09-27
# 2013-09-28
# 2013-09-29
# 2013-09-30
# 2013-10-01
# 2013-10-02
# 2013-10-03
# 2013-10-04
# 2013-10-05
# 2013-10-06
# 2013-10-07
# 2013-10-08
# 2013-10-09
# 2013-10-10
# 2013-10-11
# 2013-10-12
# 2013-10-13
# 2013-10-14
# 2013-10-15
# 2013-10-16
# 2013-10-17
# 2013-10-18
# 2013-10-19
# 2013-10-20
# 2013-10-21
# 2013-10-22
# 2013-10-23
# 2013-10-24
# 2013-10-25
# 2013-10-26
# 2013-10-27
# 2013-10-28
# 2013-10-29
# 2013-10-30
# 2013-10-31
# 2013-11-01
# 2013-11-02
# 2013-11-03
# 2013-11-04
# 2013-11-05
# 2013-11-06
# 2013-11-07
# 2013-11-08
# 2013-11-09
# 2013-11-10
# 2013-11-11
# 2013-11-12
# 2013-11-13
# 2013-11-14
# 2013-11-15
# 2013-11-16
# 2013-11-17
# 2013-11-18
# 2013-11-19
# 2013-11-20
# 2013-11-21
# 2013-11-22
# 2013-11-23
# 2013-11-24
# 2013-11-25
# 2013-11-26
# 2013-11-27
# 2013-11-28
# 2013-11-29
# 2013-11-30
# 2013-12-01
# 2013-12-02
# 2013-12-03
# 2013-12-04
# 2013-12-05
# 2013-12-06
# 2013-12-07
# 2013-12-08
# 2013-12-09
# 2013-12-10
# 2013-12-11
# 2013-12-12
# 2013-12-13
# 2013-12-14
# 2013-12-15
# 2013-12-16
# 2013-12-17
# 2013-12-18
# 2013-12-19
# 2013-12-20
# 2013-12-21
# 2013-12-22
# 2013-12-23
# 2013-12-24
# 2013-12-25
# 2013-12-26
# 2013-12-27
# 2013-12-28
# 2013-12-29
# 2013-12-30
# 2013-12-31

# %% [markdown]
# # 1.2 Check remained missing data

# %%
new_frame = data.copy()
is_missing = False

for i in range(new_frame.shape[0] - 1):
            # identify index of missing data
            dif = (new_frame.index[i+1] - new_frame.index[i]).seconds/60
            if dif > 5:
                num_mis = dif/5 - 1 # amount of missing data
                print('Time i\t\t',new_frame.index[i])
                print('Time i+1\t',new_frame.index[i+1])
                
                is_missing = True

# %% [markdown]
# # 1.3 Remove night time

# %%
# Observe some data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103968 entries, 2013-01-01 00:00:00 to 2013-12-31 23:55:00
# Data columns (total 1 columns):
# power_kW    51241 non-null float64
# dtypes: float64(1)
# memory usage: 1.6 MB

# %%
# Observe some data
data = data.fillna(0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103968 entries, 2013-01-01 00:00:00 to 2013-12-31 23:55:00
# Data columns (total 1 columns):
# power_kW    103968 non-null float64
# dtypes: float64(1)
# memory usage: 1.6 MB

# %%
## Define night time by --> set(whole_day_time) - set(day_time)
'''
This cell will calculate result dataframe which merge is_daytime boolean
'''
# Group data by day
data_grouped = data.groupby(pd.Grouper(freq='D'))
group_keys = data_grouped.groups.keys()

date_start = pd.to_datetime('2013-01-01 00:00:00')
pv_day = data_grouped.get_group(date_start)
day_time = pv_day != 0

count = 0
for key in group_keys:
    
    # Some day is missing and raise an error if key is the missing day
    # so except that missing day using try, except
    try:
        pv_day_temp = data_grouped.get_group(key)
        
        # find first and last index of day time for every day
        for i in range(288):
            if abs(pv_day_temp.iloc[i,0]) > 10e-4:
                first_index = i
                break
        for i in range(287,-1,-1):
            if abs(pv_day_temp.iloc[i,0]) > 10e-4:
                last_index = i
                break
        
        day_time = pv_day_temp.copy()
        # Define is_daytime
        day_time.iloc[first_index:last_index,0] = True
        day_time.iloc[:first_index-1,0] = False
        day_time.iloc[last_index-1:,0] = False
        
        # merge is_daytime to data
        day_time.index = pv_day_temp.index
        day_time.columns = ['is_daytime']
        
        if count == 0:
            result = pd.merge(pv_day_temp, day_time, left_index=True, right_index=True)
        else:
            result = pd.concat([result,
                                pd.merge(pv_day_temp, day_time, left_index=True, right_index=True)])
        count += 1
    except KeyError:
        pass

## Visualize result
result
# Out:
#                      power_kW is_daytime
# datetime
# 2013-01-01 00:00:00       0.0      False
# 2013-01-01 00:05:00       0.0      False
# 2013-01-01 00:10:00       0.0      False
# 2013-01-01 00:15:00       0.0      False
# 2013-01-01 00:20:00       0.0      False
# 2013-01-01 00:25:00       0.0      False
# 2013-01-01 00:30:00       0.0      False
# 2013-01-01 00:35:00       0.0      False
# 2013-01-01 00:40:00       0.0      False
# 2013-01-01 00:45:00       0.0      False
# 2013-01-01 00:50:00       0.0      False
# 2013-01-01 00:55:00       0.0      False
# 2013-01-01 01:00:00       0.0      False
# 2013-01-01 01:05:00       0.0      False
# 2013-01-01 01:10:00       0.0      False
# 2013-01-01 01:15:00       0.0      False
# 2013-01-01 01:20:00       0.0      False
# 2013-01-01 01:25:00       0.0      False
# 2013-01-01 01:30:00       0.0      False
# 2013-01-01 01:35:00       0.0      False
# 2013-01-01 01:40:00       0.0      False
# 2013-01-01 01:45:00       0.0      False
# 2013-01-01 01:50:00       0.0      False
# 2013-01-01 01:55:00       0.0      False
# 2013-01-01 02:00:00       0.0      False
# 2013-01-01 02:05:00       0.0      False
# 2013-01-01 02:10:00       0.0      False
# 2013-01-01 02:15:00       0.0      False
# 2013-01-01 02:20:00       0.0      False
# 2013-01-01 02:25:00       0.0      False
# ...                       ...        ...
# 2013-12-31 21:30:00       0.0      False
# 2013-12-31 21:35:00       0.0      False
# 2013-12-31 21:40:00       0.0      False
# 2013-12-31 21:45:00       0.0      False
# 2013-12-31 21:50:00       0.0      False
# 2013-12-31 21:55:00       0.0      False
# 2013-12-31 22:00:00       0.0      False
# 2013-12-31 22:05:00       0.0      False
# 2013-12-31 22:10:00       0.0      False
# 2013-12-31 22:15:00       0.0      False
# 2013-12-31 22:20:00       0.0      False
# 2013-12-31 22:25:00       0.0      False
# 2013-12-31 22:30:00       0.0      False
# 2013-12-31 22:35:00       0.0      False
# 2013-12-31 22:40:00       0.0      False
# 2013-12-31 22:45:00       0.0      False
# 2013-12-31 22:50:00       0.0      False
# 2013-12-31 22:55:00       0.0      False
# 2013-12-31 23:00:00       0.0      False
# 2013-12-31 23:05:00       0.0      False
# 2013-12-31 23:10:00       0.0      False
# 2013-12-31 23:15:00       0.0      False
# 2013-12-31 23:20:00       0.0      False
# 2013-12-31 23:25:00       0.0      False
# 2013-12-31 23:30:00       0.0      False
# 2013-12-31 23:35:00       0.0      False
# 2013-12-31 23:40:00       0.0      False
# 2013-12-31 23:45:00       0.0      False
# 2013-12-31 23:50:00       0.0      False
# 2013-12-31 23:55:00       0.0      False
#
# [103968 rows x 2 columns]

# %%
'''
Now it's time to remove night time by remove False row of is_daytime columns!
'''
# Group result data by day
data_daytime = result.loc[result['is_daytime']==True,:]
for i in range(len(data_daytime)):
    print(data_daytime.iloc[i,:])
# Out:
# power_kW      0.02779
# is_daytime       True
# Name: 2013-01-01 07:30:00, dtype: object
# power_kW      0.04902
# is_daytime       True
# Name: 2013-01-01 07:35:00, dtype: object
# power_kW      0.07209
# is_daytime       True
# Name: 2013-01-01 07:40:00, dtype: object
# power_kW      0.09013
# is_daytime       True
# Name: 2013-01-01 07:45:00, dtype: object
# power_kW      0.10483
# is_daytime       True
# Name: 2013-01-01 07:50:00, dtype: object
# power_kW      0.11588
# is_daytime       True
# Name: 2013-01-01 07:55:00, dtype: object
# power_kW      0.15139
# is_daytime       True
# Name: 2013-01-01 08:00:00, dtype: object
# power_kW      0.17766
# is_daytime       True
# Name: 2013-01-01 08:05:00, dtype: object
# power_kW      0.2468
# is_daytime      True
# Name: 2013-01-01 08:10:00, dtype: object
# power_kW      0.29613
# is_daytime       True
# Name: 2013-01-01 08:15:00, dtype: object
# power_kW      0.2903
# is_daytime      True
# Name: 2013-01-01 08:20:00, dtype: object
# power_kW      0.25008
# is_daytime       True
# Name: 2013-01-01 08:25:00, dtype: object
# power_kW      0.23051
# is_daytime       True
# Name: 2013-01-01 08:30:00, dtype: object
# power_kW      0.246
# is_daytime     True
# Name: 2013-01-01 08:35:00, dtype: object
# power_kW      0.20465
# is_daytime       True
# Name: 2013-01-01 08:40:00, dtype: object
# power_kW      0.33846
# is_daytime       True
# Name: 2013-01-01 08:45:00, dtype: object
# power_kW      0.29104
# is_daytime       True
# Name: 2013-01-01 08:50:00, dtype: object
# power_kW      0.3896
# is_daytime      True
# Name: 2013-01-01 08:55:00, dtype: object
# power_kW      0.43225
# is_daytime       True
# Name: 2013-01-01 09:00:00, dtype: object
# power_kW      0.48315
# is_daytime       True
# Name: 2013-01-01 09:05:00, dtype: object
# power_kW      0.40645
# is_daytime       True
# Name: 2013-01-01 09:10:00, dtype: object
# power_kW      0.4318
# is_daytime      True
# Name: 2013-01-01 09:15:00, dtype: object
# power_kW      0.41355
# is_daytime       True
# Name: 2013-01-01 09:20:00, dtype: object
# power_kW      0.4048
# is_daytime      True
# Name: 2013-01-01 09:25:00, dtype: object
# power_kW      0.23721
# is_daytime       True
# Name: 2013-01-01 09:30:00, dtype: object
# power_kW      0.43727
# is_daytime       True
# Name: 2013-01-01 09:35:00, dtype: object
# power_kW      0.67926
# is_daytime       True
# Name: 2013-01-01 09:40:00, dtype: object
# power_kW      0.68114
# is_daytime       True
# Name: 2013-01-01 09:45:00, dtype: object
# power_kW      0.68376
# is_daytime       True
# Name: 2013-01-01 09:50:00, dtype: object
# power_kW      0.66315
# is_daytime       True
# Name: 2013-01-01 09:55:00, dtype: object
# power_kW      0.48666
# is_daytime       True
# Name: 2013-01-01 10:00:00, dtype: object
# power_kW      0.6279
# is_daytime      True
# Name: 2013-01-01 10:05:00, dtype: object
# power_kW      0.77184
# is_daytime       True
# Name: 2013-01-01 10:10:00, dtype: object
# power_kW      0.76363
# is_daytime       True
# Name: 2013-01-01 10:15:00, dtype: object
# power_kW      0.77102
# is_daytime       True
# Name: 2013-01-01 10:20:00, dtype: object
# power_kW      0.76127
# is_daytime       True
# Name: 2013-01-01 10:25:00, dtype: object
# power_kW      0.76951
# is_daytime       True
# Name: 2013-01-01 10:30:00, dtype: object
# power_kW      0.75527
# is_daytime       True
# Name: 2013-01-01 10:35:00, dtype: object
# power_kW      0.7778
# is_daytime      True
# Name: 2013-01-01 10:40:00, dtype: object
# power_kW      0.78982
# is_daytime       True
# Name: 2013-01-01 10:45:00, dtype: object
# power_kW      0.77825
# is_daytime       True
# Name: 2013-01-01 10:50:00, dtype: object
# power_kW      0.82312
# is_daytime       True
# Name: 2013-01-01 10:55:00, dtype: object
# power_kW      0.85116
# is_daytime       True
# Name: 2013-01-01 11:00:00, dtype: object
# power_kW      0.83391
# is_daytime       True
# Name: 2013-01-01 11:05:00, dtype: object
# power_kW      0.84428
# is_daytime       True
# Name: 2013-01-01 11:10:00, dtype: object
# power_kW      0.85074
# is_daytime       True
# Name: 2013-01-01 11:15:00, dtype: object
# power_kW      0.86933
# is_daytime       True
# Name: 2013-01-01 11:20:00, dtype: object
# power_kW      0.88647
# is_daytime       True
# Name: 2013-01-01 11:25:00, dtype: object
# power_kW      0.88405
# is_daytime       True
# Name: 2013-01-01 11:30:00, dtype: object
# power_kW      0.87565
# is_daytime       True
# Name: 2013-01-01 11:35:00, dtype: object
# power_kW      0.85022
# is_daytime       True
# Name: 2013-01-01 11:40:00, dtype: object
# power_kW      0.8615
# is_daytime      True
# Name: 2013-01-01 11:45:00, dtype: object
# power_kW      0.88843
# is_daytime       True
# Name: 2013-01-01 11:50:00, dtype: object
# power_kW      0.91724
# is_daytime       True
# Name: 2013-01-01 11:55:00, dtype: object
# power_kW      0.91918
# is_daytime       True
# Name: 2013-01-01 12:00:00, dtype: object
# power_kW      0.93611
# is_daytime       True
# Name: 2013-01-01 12:05:00, dtype: object
# power_kW      0.94367
# is_daytime       True
# Name: 2013-01-01 12:10:00, dtype: object
# power_kW      0.8782
# is_daytime      True
# Name: 2013-01-01 12:15:00, dtype: object
# power_kW      0.89587
# is_daytime       True
# Name: 2013-01-01 12:20:00, dtype: object
# power_kW      0.90388
# is_daytime       True
# Name: 2013-01-01 12:25:00, dtype: object
# power_kW      0.895
# is_daytime     True
# Name: 2013-01-01 12:30:00, dtype: object
# power_kW      0.89822
# is_daytime       True
# Name: 2013-01-01 12:35:00, dtype: object
# power_kW      0.89218
# is_daytime       True
# Name: 2013-01-01 12:40:00, dtype: object
# power_kW      0.88198
# is_daytime       True
# Name: 2013-01-01 12:45:00, dtype: object
# power_kW      0.87061
# is_daytime       True
# Name: 2013-01-01 12:50:00, dtype: object
# power_kW      0.85924
# is_daytime       True
# Name: 2013-01-01 12:55:00, dtype: object
# power_kW      0.86313
# is_daytime       True
# Name: 2013-01-01 13:00:00, dtype: object
# power_kW      0.86169
# is_daytime       True
# Name: 2013-01-01 13:05:00, dtype: object
# power_kW      0.84476
# is_daytime       True
# Name: 2013-01-01 13:10:00, dtype: object
# power_kW      0.83523
# is_daytime       True
# Name: 2013-01-01 13:15:00, dtype: object
# power_kW      0.85621
# is_daytime       True
# Name: 2013-01-01 13:20:00, dtype: object
# power_kW      0.83073
# is_daytime       True
# Name: 2013-01-01 13:25:00, dtype: object
# power_kW      0.81769
# is_daytime       True
# Name: 2013-01-01 13:30:00, dtype: object
# power_kW      0.88
# is_daytime    True
# Name: 2013-01-01 13:35:00, dtype: object
# power_kW      0.82278
# is_daytime       True
# Name: 2013-01-01 13:40:00, dtype: object
# power_kW      0.61343
# is_daytime       True
# Name: 2013-01-01 13:45:00, dtype: object
# power_kW      0.63778
# is_daytime       True
# Name: 2013-01-01 13:50:00, dtype: object
# power_kW      0.59696
# is_daytime       True
# Name: 2013-01-01 13:55:00, dtype: object
# power_kW      0.56493
# is_daytime       True
# Name: 2013-01-01 14:00:00, dtype: object
# power_kW      0.77625
# is_daytime       True
# Name: 2013-01-01 14:05:00, dtype: object
# power_kW      0.82604
# is_daytime       True
# Name: 2013-01-01 14:10:00, dtype: object
# power_kW      0.79431
# is_daytime       True
# Name: 2013-01-01 14:15:00, dtype: object
# power_kW      0.70955
# is_daytime       True
# Name: 2013-01-01 14:20:00, dtype: object
# power_kW      0.74289
# is_daytime       True
# Name: 2013-01-01 14:25:00, dtype: object
# power_kW      0.74787
# is_daytime       True
# Name: 2013-01-01 14:30:00, dtype: object
# power_kW      0.71471
# is_daytime       True
# Name: 2013-01-01 14:35:00, dtype: object
# power_kW      0.68058
# is_daytime       True
# Name: 2013-01-01 14:40:00, dtype: object
# power_kW      0.68804
# is_daytime       True
# Name: 2013-01-01 14:45:00, dtype: object
# power_kW      0.69293
# is_daytime       True
# Name: 2013-01-01 14:50:00, dtype: object
# power_kW      0.67692
# is_daytime       True
# Name: 2013-01-01 14:55:00, dtype: object
# power_kW      0.66816
# is_daytime       True
# Name: 2013-01-01 15:00:00, dtype: object
# power_kW      0.64115
# is_daytime       True
# Name: 2013-01-01 15:05:00, dtype: object
# power_kW      0.61561
# is_daytime       True
# Name: 2013-01-01 15:10:00, dtype: object
# power_kW      0.61498
# is_daytime       True
# Name: 2013-01-01 15:15:00, dtype: object
# power_kW      0.595
# is_daytime     True
# Name: 2013-01-01 15:20:00, dtype: object
# power_kW      0.57165
# is_daytime       True
# Name: 2013-01-01 15:25:00, dtype: object
# power_kW      0.55905
# is_daytime       True
# Name: 2013-01-01 15:30:00, dtype: object
# power_kW      0.53753
# is_daytime       True
# Name: 2013-01-01 15:35:00, dtype: object
# power_kW      0.52064
# is_daytime       True
# Name: 2013-01-01 15:40:00, dtype: object
# power_kW      0.50007
# is_daytime       True
# Name: 2013-01-01 15:45:00, dtype: object
# power_kW      0.48445
# is_daytime       True
# Name: 2013-01-01 15:50:00, dtype: object
# power_kW      0.46412
# is_daytime       True
# Name: 2013-01-01 15:55:00, dtype: object
# power_kW      0.44122
# is_daytime       True
# Name: 2013-01-01 16:00:00, dtype: object
# power_kW      0.42556
# is_daytime       True
# Name: 2013-01-01 16:05:00, dtype: object
# power_kW      0.40079
# is_daytime       True
# Name: 2013-01-01 16:10:00, dtype: object
# power_kW      0.37775
# is_daytime       True
# Name: 2013-01-01 16:15:00, dtype: object
# power_kW      0.34109
# is_daytime       True
# Name: 2013-01-01 16:20:00, dtype: object
# power_kW      0.31743
# is_daytime       True
# Name: 2013-01-01 16:25:00, dtype: object
# power_kW      0.2966
# is_daytime      True
# Name: 2013-01-01 16:30:00, dtype: object
# power_kW      0.27852
# is_daytime       True
# Name: 2013-01-01 16:35:00, dtype: object
# power_kW      0.23355
# is_daytime       True
# Name: 2013-01-01 16:40:00, dtype: object
# power_kW      0.20518
# is_daytime       True
# Name: 2013-01-01 16:45:00, dtype: object
# power_kW      0.20764
# is_daytime       True
# Name: 2013-01-01 16:50:00, dtype: object
# power_kW      0.17273
# is_daytime       True
# Name: 2013-01-01 16:55:00, dtype: object
# power_kW      0.14705
# is_daytime       True
# Name: 2013-01-01 17:00:00, dtype: object
# power_kW      0.13118
# is_daytime       True
# Name: 2013-01-01 17:05:00, dtype: object
# power_kW      0.11482
# is_daytime       True
# Name: 2013-01-01 17:10:00, dtype: object
# power_kW      0.08925
# is_daytime       True
# Name: 2013-01-01 17:15:00, dtype: object
# power_kW      0.05322
# is_daytime       True
# Name: 2013-01-01 17:20:00, dtype: object
# power_kW      0.0138
# is_daytime      True
# Name: 2013-01-02 07:25:00, dtype: object
# power_kW      0.01735
# is_daytime       True
# Name: 2013-01-02 07:30:00, dtype: object
# power_kW      0.02329
# is_daytime       True
# Name: 2013-01-02 07:35:00, dtype: object
# power_kW      0.03063
# is_daytime       True
# Name: 2013-01-02 07:40:00, dtype: object
# power_kW      0.04189
# is_daytime       True
# Name: 2013-01-02 07:45:00, dtype: object
# power_kW      0.05329
# is_daytime       True
# Name: 2013-01-02 07:50:00, dtype: object
# power_kW      0.07161
# is_daytime       True
# Name: 2013-01-02 07:55:00, dtype: object
# power_kW      0.13025
# is_daytime       True
# Name: 2013-01-02 08:00:00, dtype: object
# power_kW      0.17274
# is_daytime       True
# Name: 2013-01-02 08:05:00, dtype: object
# power_kW      0.21133
# is_daytime       True
# Name: 2013-01-02 08:10:00, dtype: object
# power_kW      0.25405
# is_daytime       True
# Name: 2013-01-02 08:15:00, dtype: object
# power_kW      0.28169
# is_daytime       True
# Name: 2013-01-02 08:20:00, dtype: object
# power_kW      0.31154
# is_daytime       True
# Name: 2013-01-02 08:25:00, dtype: object
# power_kW      0.33362
# is_daytime       True
# Name: 2013-01-02 08:30:00, dtype: object
# power_kW      0.34963
# is_daytime       True
# Name: 2013-01-02 08:35:00, dtype: object
# power_kW      0.37714
# is_daytime       True
# Name: 2013-01-02 08:40:00, dtype: object
# power_kW      0.3988
# is_daytime      True
# Name: 2013-01-02 08:45:00, dtype: object
# power_kW      0.41807
# is_daytime       True
# Name: 2013-01-02 08:50:00, dtype: object
# power_kW      0.44323
# is_daytime       True
# Name: 2013-01-02 08:55:00, dtype: object
# power_kW      0.464
# is_daytime     True
# Name: 2013-01-02 09:00:00, dtype: object
# power_kW      0.48388
# is_daytime       True
# Name: 2013-01-02 09:05:00, dtype: object
# power_kW      0.4951
# is_daytime      True
# Name: 2013-01-02 09:10:00, dtype: object
# power_kW      0.5085
# is_daytime      True
# Name: 2013-01-02 09:15:00, dtype: object
# power_kW      0.52798
# is_daytime       True
# Name: 2013-01-02 09:20:00, dtype: object
# power_kW      0.54171
# is_daytime       True
# Name: 2013-01-02 09:25:00, dtype: object
# power_kW      0.56384
# is_daytime       True
# Name: 2013-01-02 09:30:00, dtype: object
# power_kW      0.58865
# is_daytime       True
# Name: 2013-01-02 09:35:00, dtype: object
# power_kW      0.59302
# is_daytime       True
# Name: 2013-01-02 09:40:00, dtype: object
# power_kW      0.60253
# is_daytime       True
# Name: 2013-01-02 09:45:00, dtype: object
# power_kW      0.6283
# is_daytime      True
# Name: 2013-01-02 09:50:00, dtype: object
# power_kW      0.64171
# is_daytime       True
# Name: 2013-01-02 09:55:00, dtype: object
# power_kW      0.65337
# is_daytime       True
# Name: 2013-01-02 10:00:00, dtype: object
# power_kW      0.67446
# is_daytime       True
# Name: 2013-01-02 10:05:00, dtype: object
# power_kW      0.69269
# is_daytime       True
# Name: 2013-01-02 10:10:00, dtype: object
# power_kW      0.70845
# is_daytime       True
# Name: 2013-01-02 10:15:00, dtype: object
# power_kW      0.71856
# is_daytime       True
# Name: 2013-01-02 10:20:00, dtype: object
# power_kW      0.73508
# is_daytime       True
# Name: 2013-01-02 10:25:00, dtype: object
# power_kW      0.74677
# is_daytime       True
# Name: 2013-01-02 10:30:00, dtype: object
# power_kW      0.76047
# is_daytime       True
# Name: 2013-01-02 10:35:00, dtype: object
# power_kW      0.7656
# is_daytime      True
# Name: 2013-01-02 10:40:00, dtype: object
# power_kW      0.7724
# is_daytime      True
# Name: 2013-01-02 10:45:00, dtype: object
# power_kW      0.77338
# is_daytime       True
# Name: 2013-01-02 10:50:00, dtype: object
# power_kW      0.77667
# is_daytime       True
# Name: 2013-01-02 10:55:00, dtype: object
# power_kW      0.78181
# is_daytime       True
# Name: 2013-01-02 11:00:00, dtype: object
# power_kW      0.79367
# is_daytime       True
# Name: 2013-01-02 11:05:00, dtype: object
# power_kW      0.79605
# is_daytime       True
# Name: 2013-01-02 11:10:00, dtype: object
# power_kW      0.80496
# is_daytime       True
# Name: 2013-01-02 11:15:00, dtype: object
# power_kW      0.81825
# is_daytime       True
# Name: 2013-01-02 11:20:00, dtype: object
# power_kW      0.82855
# is_daytime       True
# Name: 2013-01-02 11:25:00, dtype: object
# power_kW      0.82961
# is_daytime       True
# Name: 2013-01-02 11:30:00, dtype: object
# power_kW      0.82558
# is_daytime       True
# Name: 2013-01-02 11:35:00, dtype: object
# power_kW      0.82336
# is_daytime       True
# Name: 2013-01-02 11:40:00, dtype: object
# power_kW      0.82596
# is_daytime       True
# Name: 2013-01-02 11:45:00, dtype: object
# power_kW      0.83956
# is_daytime       True
# Name: 2013-01-02 11:50:00, dtype: object
# power_kW      0.85544
# is_daytime       True
# Name: 2013-01-02 11:55:00, dtype: object
# power_kW      0.85181
# is_daytime       True
# Name: 2013-01-02 12:00:00, dtype: object
# power_kW      0.84087
# is_daytime       True
# Name: 2013-01-02 12:05:00, dtype: object
# power_kW      0.86121
# is_daytime       True
# Name: 2013-01-02 12:10:00, dtype: object
# power_kW      0.8499
# is_daytime      True
# Name: 2013-01-02 12:15:00, dtype: object
# power_kW      0.85029
# is_daytime       True
# Name: 2013-01-02 12:20:00, dtype: object
# power_kW      0.86408
# is_daytime       True
# Name: 2013-01-02 12:25:00, dtype: object
# power_kW      0.85492
# is_daytime       True
# Name: 2013-01-02 12:30:00, dtype: object
# power_kW      0.86055
# is_daytime       True
# Name: 2013-01-02 12:35:00, dtype: object
# power_kW      0.86708
# is_daytime       True
# Name: 2013-01-02 12:40:00, dtype: object
# power_kW      0.8531
# is_daytime      True
# Name: 2013-01-02 12:45:00, dtype: object
# power_kW      0.84588
# is_daytime       True
# Name: 2013-01-02 12:50:00, dtype: object
# power_kW      0.8523
# is_daytime      True
# Name: 2013-01-02 12:55:00, dtype: object
# power_kW      0.85615
# is_daytime       True
# Name: 2013-01-02 13:00:00, dtype: object
# power_kW      0.85646
# is_daytime       True
# Name: 2013-01-02 13:05:00, dtype: object
# power_kW      0.84498
# is_daytime       True
# Name: 2013-01-02 13:10:00, dtype: object
# power_kW      0.83025
# is_daytime       True
# Name: 2013-01-02 13:15:00, dtype: object
# power_kW      0.81872
# is_daytime       True
# Name: 2013-01-02 13:20:00, dtype: object
# power_kW      0.81733
# is_daytime       True
# Name: 2013-01-02 13:25:00, dtype: object
# power_kW      0.82196
# is_daytime       True
# Name: 2013-01-02 13:30:00, dtype: object
# power_kW      0.81287
# is_daytime       True
# Name: 2013-01-02 13:35:00, dtype: object
# power_kW      0.79563
# is_daytime       True
# Name: 2013-01-02 13:40:00, dtype: object
# power_kW      0.79936
# is_daytime       True
# Name: 2013-01-02 13:45:00, dtype: object
# power_kW      0.79076
# is_daytime       True
# Name: 2013-01-02 13:50:00, dtype: object
# power_kW      0.77751
# is_daytime       True
# Name: 2013-01-02 13:55:00, dtype: object
# power_kW      0.76216
# is_daytime       True
# Name: 2013-01-02 14:00:00, dtype: object
# power_kW      0.76138
# is_daytime       True
# Name: 2013-01-02 14:05:00, dtype: object
# power_kW      0.72787
# is_daytime       True
# Name: 2013-01-02 14:10:00, dtype: object
# power_kW      0.71907
# is_daytime       True
# Name: 2013-01-02 14:15:00, dtype: object
# power_kW      0.72625
# is_daytime       True
# Name: 2013-01-02 14:20:00, dtype: object
# power_kW      0.71028
# is_daytime       True
# Name: 2013-01-02 14:25:00, dtype: object
# power_kW      0.70119
# is_daytime       True
# Name: 2013-01-02 14:30:00, dtype: object
# power_kW      0.68582
# is_daytime       True
# Name: 2013-01-02 14:35:00, dtype: object
# power_kW      0.67619
# is_daytime       True
# Name: 2013-01-02 14:40:00, dtype: object
# power_kW      0.67025
# is_daytime       True
# Name: 2013-01-02 14:45:00, dtype: object
# power_kW      0.66432
# is_daytime       True
# Name: 2013-01-02 14:50:00, dtype: object
# power_kW      0.63815
# is_daytime       True
# Name: 2013-01-02 14:55:00, dtype: object
# power_kW      0.64127
# is_daytime       True
# Name: 2013-01-02 15:00:00, dtype: object
# power_kW      0.64396
# is_daytime       True
# Name: 2013-01-02 15:05:00, dtype: object
# power_kW      0.62187
# is_daytime       True
# Name: 2013-01-02 15:10:00, dtype: object
# power_kW      0.60389
# is_daytime       True
# Name: 2013-01-02 15:15:00, dtype: object
# power_kW      0.56943
# is_daytime       True
# Name: 2013-01-02 15:20:00, dtype: object
# power_kW      0.56672
# is_daytime       True
# Name: 2013-01-02 15:25:00, dtype: object
# power_kW      0.54256
# is_daytime       True
# Name: 2013-01-02 15:30:00, dtype: object
# power_kW      0.51226
# is_daytime       True
# Name: 2013-01-02 15:35:00, dtype: object
# power_kW      0.48905
# is_daytime       True
# Name: 2013-01-02 15:40:00, dtype: object
# power_kW      0.48392
# is_daytime       True
# Name: 2013-01-02 15:45:00, dtype: object
# power_kW      0.43954
# is_daytime       True
# Name: 2013-01-02 15:50:00, dtype: object
# power_kW      0.43369
# is_daytime       True
# Name: 2013-01-02 15:55:00, dtype: object
# power_kW      0.43198
# is_daytime       True
# Name: 2013-01-02 16:00:00, dtype: object
# power_kW      0.40885
# is_daytime       True
# Name: 2013-01-02 16:05:00, dtype: object
# power_kW      0.38698
# is_daytime       True
# Name: 2013-01-02 16:10:00, dtype: object
# power_kW      0.36462
# is_daytime       True
# Name: 2013-01-02 16:15:00, dtype: object
# power_kW      0.341
# is_daytime     True
# Name: 2013-01-02 16:20:00, dtype: object
# power_kW      0.31152
# is_daytime       True
# Name: 2013-01-02 16:25:00, dtype: object
# power_kW      0.2838
# is_daytime      True
# Name: 2013-01-02 16:30:00, dtype: object
# power_kW      0.27473
# is_daytime       True
# Name: 2013-01-02 16:35:00, dtype: object
# power_kW      0.25059
# is_daytime       True
# Name: 2013-01-02 16:40:00, dtype: object
# power_kW      0.22675
# is_daytime       True
# Name: 2013-01-02 16:45:00, dtype: object
# power_kW      0.21039
# is_daytime       True
# Name: 2013-01-02 16:50:00, dtype: object
# power_kW      0.18631
# is_daytime       True
# Name: 2013-01-02 16:55:00, dtype: object
# power_kW      0.16115
# is_daytime       True
# Name: 2013-01-02 17:00:00, dtype: object
# power_kW      0.13613
# is_daytime       True
# Name: 2013-01-02 17:05:00, dtype: object
# power_kW      0.1103
# is_daytime      True
# Name: 2013-01-02 17:10:00, dtype: object
# power_kW      0.01124
# is_daytime       True
# Name: 2013-01-03 07:15:00, dtype: object
# power_kW      0.02013
# is_daytime       True
# Name: 2013-01-03 07:20:00, dtype: object
# power_kW      0.02178
# is_daytime       True
# Name: 2013-01-03 07:25:00, dtype: object
# power_kW      0.02825
# is_daytime       True
# Name: 2013-01-03 07:30:00, dtype: object
# power_kW      0.04855
# is_daytime       True
# Name: 2013-01-03 07:35:00, dtype: object
# power_kW      0.05663
# is_daytime       True
# Name: 2013-01-03 07:40:00, dtype: object
# power_kW      0.06298
# is_daytime       True
# Name: 2013-01-03 07:45:00, dtype: object
# power_kW      0.07414
# is_daytime       True
# Name: 2013-01-03 07:50:00, dtype: object
# power_kW      0.08767
# is_daytime       True
# Name: 2013-01-03 07:55:00, dtype: object
# power_kW      0.10463
# is_daytime       True
# Name: 2013-01-03 08:00:00, dtype: object
# power_kW      0.16191
# is_daytime       True
# Name: 2013-01-03 08:05:00, dtype: object
# power_kW      0.18978
# is_daytime       True
# Name: 2013-01-03 08:10:00, dtype: object
# power_kW      0.21765
# is_daytime       True
# Name: 2013-01-03 08:15:00, dtype: object
# power_kW      0.27054
# is_daytime       True
# Name: 2013-01-03 08:20:00, dtype: object
# power_kW      0.29061
# is_daytime       True
# Name: 2013-01-03 08:25:00, dtype: object
# power_kW      0.31496
# is_daytime       True
# Name: 2013-01-03 08:30:00, dtype: object
# power_kW      0.33096
# is_daytime       True
# Name: 2013-01-03 08:35:00, dtype: object
# power_kW      0.33171
# is_daytime       True
# Name: 2013-01-03 08:40:00, dtype: object
# power_kW      0.37327
# is_daytime       True
# Name: 2013-01-03 08:45:00, dtype: object
# power_kW      0.37804
# is_daytime       True
# Name: 2013-01-03 08:50:00, dtype: object
# power_kW      0.40149
# is_daytime       True
# Name: 2013-01-03 08:55:00, dtype: object
# power_kW      0.42711
# is_daytime       True
# Name: 2013-01-03 09:00:00, dtype: object
# power_kW      0.45265
# is_daytime       True
# Name: 2013-01-03 09:05:00, dtype: object
# power_kW      0.44927
# is_daytime       True
# Name: 2013-01-03 09:10:00, dtype: object
# power_kW      0.49552
# is_daytime       True
# Name: 2013-01-03 09:15:00, dtype: object
# power_kW      0.51531
# is_daytime       True
# Name: 2013-01-03 09:20:00, dtype: object
# power_kW      0.52578
# is_daytime       True
# Name: 2013-01-03 09:25:00, dtype: object
# power_kW      0.54896
# is_daytime       True
# Name: 2013-01-03 09:30:00, dtype: object
# power_kW      0.56238
# is_daytime       True
# Name: 2013-01-03 09:35:00, dtype: object
# power_kW      0.58896
# is_daytime       True
# Name: 2013-01-03 09:40:00, dtype: object
# power_kW      0.57556
# is_daytime       True
# Name: 2013-01-03 09:45:00, dtype: object
# power_kW      0.55627
# is_daytime       True
# Name: 2013-01-03 09:50:00, dtype: object
# power_kW      0.60255
# is_daytime       True
# Name: 2013-01-03 09:55:00, dtype: object
# power_kW      0.58958
# is_daytime       True
# Name: 2013-01-03 10:00:00, dtype: object
# power_kW      0.60073
# is_daytime       True
# Name: 2013-01-03 10:05:00, dtype: object
# power_kW      0.62041
# is_daytime       True
# Name: 2013-01-03 10:10:00, dtype: object
# power_kW      0.68544
# is_daytime       True
# Name: 2013-01-03 10:15:00, dtype: object
# power_kW      0.71167
# is_daytime       True
# Name: 2013-01-03 10:20:00, dtype: object
# power_kW      0.73063
# is_daytime       True
# Name: 2013-01-03 10:25:00, dtype: object
# power_kW      0.77097
# is_daytime       True
# Name: 2013-01-03 10:30:00, dtype: object
# power_kW      0.79108
# is_daytime       True
# Name: 2013-01-03 10:35:00, dtype: object
# power_kW      0.80992
# is_daytime       True
# Name: 2013-01-03 10:40:00, dtype: object
# power_kW      0.82286
# is_daytime       True
# Name: 2013-01-03 10:45:00, dtype: object
# power_kW      0.74317
# is_daytime       True
# Name: 2013-01-03 10:50:00, dtype: object
# power_kW      0.75549
# is_daytime       True
# Name: 2013-01-03 10:55:00, dtype: object
# power_kW      0.74867
# is_daytime       True
# Name: 2013-01-03 11:00:00, dtype: object
# power_kW      0.79588
# is_daytime       True
# Name: 2013-01-03 11:05:00, dtype: object
# power_kW      0.78188
# is_daytime       True
# Name: 2013-01-03 11:10:00, dtype: object
# power_kW      0.62825
# is_daytime       True
# Name: 2013-01-03 11:15:00, dtype: object
# power_kW      0.66027
# is_daytime       True
# Name: 2013-01-03 11:20:00, dtype: object
# power_kW      0.78506
# is_daytime       True
# Name: 2013-01-03 11:25:00, dtype: object
# power_kW      0.87855
# is_daytime       True
# Name: 2013-01-03 11:30:00, dtype: object
# power_kW      0.79724
# is_daytime       True
# Name: 2013-01-03 11:35:00, dtype: object
# power_kW      0.82251
# is_daytime       True
# Name: 2013-01-03 11:40:00, dtype: object
# power_kW      0.89029
# is_daytime       True
# Name: 2013-01-03 11:45:00, dtype: object
# power_kW      0.8944
# is_daytime      True
# Name: 2013-01-03 11:50:00, dtype: object
# power_kW      0.84763
# is_daytime       True
# Name: 2013-01-03 11:55:00, dtype: object
# power_kW      0.88826
# is_daytime       True
# Name: 2013-01-03 12:00:00, dtype: object
# power_kW      0.88195
# is_daytime       True
# Name: 2013-01-03 12:05:00, dtype: object
# power_kW      0.87703
# is_daytime       True
# Name: 2013-01-03 12:10:00, dtype: object
# power_kW      0.8761
# is_daytime      True
# Name: 2013-01-03 12:15:00, dtype: object
# power_kW      0.86696
# is_daytime       True
# Name: 2013-01-03 12:20:00, dtype: object
# power_kW      0.81545
# is_daytime       True
# Name: 2013-01-03 12:25:00, dtype: object
# power_kW      0.83475
# is_daytime       True
# Name: 2013-01-03 12:30:00, dtype: object
# power_kW      0.88976
# is_daytime       True
# Name: 2013-01-03 12:35:00, dtype: object
# power_kW      0.89343
# is_daytime       True
# Name: 2013-01-03 12:40:00, dtype: object
# power_kW      0.8777
# is_daytime      True
# Name: 2013-01-03 12:45:00, dtype: object
# power_kW      0.87665
# is_daytime       True
# Name: 2013-01-03 12:50:00, dtype: object
# power_kW      0.8614
# is_daytime      True
# Name: 2013-01-03 12:55:00, dtype: object
# power_kW      0.86911
# is_daytime       True
# Name: 2013-01-03 13:00:00, dtype: object
# power_kW      0.88623
# is_daytime       True
# Name: 2013-01-03 13:05:00, dtype: object
# power_kW      0.88064
# is_daytime       True
# Name: 2013-01-03 13:10:00, dtype: object
# power_kW      0.86124
# is_daytime       True
# Name: 2013-01-03 13:15:00, dtype: object
# power_kW      0.87378
# is_daytime       True
# Name: 2013-01-03 13:20:00, dtype: object
# power_kW      0.84945
# is_daytime       True
# Name: 2013-01-03 13:25:00, dtype: object
# power_kW      0.81875
# is_daytime       True
# Name: 2013-01-03 13:30:00, dtype: object
# power_kW      0.83944
# is_daytime       True
# Name: 2013-01-03 13:35:00, dtype: object
# power_kW      0.81054
# is_daytime       True
# Name: 2013-01-03 13:40:00, dtype: object
# power_kW      0.81591
# is_daytime       True
# Name: 2013-01-03 13:45:00, dtype: object
# power_kW      0.83019
# is_daytime       True
# Name: 2013-01-03 13:50:00, dtype: object
# power_kW      0.82038
# is_daytime       True
# Name: 2013-01-03 13:55:00, dtype: object
# power_kW      0.80749
# is_daytime       True
# Name: 2013-01-03 14:00:00, dtype: object
# power_kW      0.76422
# is_daytime       True
# Name: 2013-01-03 14:05:00, dtype: object
# power_kW      0.76882
# is_daytime       True
# Name: 2013-01-03 14:10:00, dtype: object
# power_kW      0.77631
# is_daytime       True
# Name: 2013-01-03 14:15:00, dtype: object
# power_kW      0.77339
# is_daytime       True
# Name: 2013-01-03 14:20:00, dtype: object
# power_kW      0.73904
# is_daytime       True
# Name: 2013-01-03 14:25:00, dtype: object
# power_kW      0.69361
# is_daytime       True
# Name: 2013-01-03 14:30:00, dtype: object
# power_kW      0.68313
# is_daytime       True
# Name: 2013-01-03 14:35:00, dtype: object
# power_kW      0.71723
# is_daytime       True
# Name: 2013-01-03 14:40:00, dtype: object
# power_kW      0.71324
# is_daytime       True
# Name: 2013-01-03 14:45:00, dtype: object
# power_kW      0.68927
# is_daytime       True
# Name: 2013-01-03 14:50:00, dtype: object
# power_kW      0.65332
# is_daytime       True
# Name: 2013-01-03 14:55:00, dtype: object
# power_kW      0.62084
# is_daytime       True
# Name: 2013-01-03 15:00:00, dtype: object
# power_kW      0.60353
# is_daytime       True
# Name: 2013-01-03 15:05:00, dtype: object
# power_kW      0.4242
# is_daytime      True
# Name: 2013-01-03 15:10:00, dtype: object
# power_kW      0.38151
# is_daytime       True
# Name: 2013-01-03 15:15:00, dtype: object
# power_kW      0.17933
# is_daytime       True
# Name: 2013-01-03 15:20:00, dtype: object
# power_kW      0.20376
# is_daytime       True
# Name: 2013-01-03 15:25:00, dtype: object
# power_kW      0.33456
# is_daytime       True
# Name: 2013-01-03 15:30:00, dtype: object
# power_kW      0.58305
# is_daytime       True
# Name: 2013-01-03 15:35:00, dtype: object
# power_kW      0.58622
# is_daytime       True
# Name: 2013-01-03 15:40:00, dtype: object
# power_kW      0.55787
# is_daytime       True
# Name: 2013-01-03 15:45:00, dtype: object
# power_kW      0.51834
# is_daytime       True
# Name: 2013-01-03 15:50:00, dtype: object
# power_kW      0.48383
# is_daytime       True
# Name: 2013-01-03 15:55:00, dtype: object
# power_kW      0.4492
# is_daytime      True
# Name: 2013-01-03 16:00:00, dtype: object
# power_kW      0.43286
# is_daytime       True
# Name: 2013-01-03 16:05:00, dtype: object
# power_kW      0.40946
# is_daytime       True
# Name: 2013-01-03 16:10:00, dtype: object
# power_kW      0.39409
# is_daytime       True
# Name: 2013-01-03 16:15:00, dtype: object
# power_kW      0.34579
# is_daytime       True
# Name: 2013-01-03 16:20:00, dtype: object
# power_kW      0.29606
# is_daytime       True
# Name: 2013-01-03 16:25:00, dtype: object
# power_kW      0.28565
# is_daytime       True
# Name: 2013-01-03 16:30:00, dtype: object
# power_kW      0.2632
# is_daytime      True
# Name: 2013-01-03 16:35:00, dtype: object
# power_kW      0.21311
# is_daytime       True
# Name: 2013-01-03 16:40:00, dtype: object
# power_kW      0.17418
# is_daytime       True
# Name: 2013-01-03 16:45:00, dtype: object
# power_kW      0.17109
# is_daytime       True
# Name: 2013-01-03 16:50:00, dtype: object
# power_kW      0.14059
# is_daytime       True
# Name: 2013-01-03 16:55:00, dtype: object
# power_kW      0.08613
# is_daytime       True
# Name: 2013-01-03 17:00:00, dtype: object
# power_kW      0.10389
# is_daytime       True
# Name: 2013-01-03 17:05:00, dtype: object
# power_kW      0.11785
# is_daytime       True
# Name: 2013-01-03 17:10:00, dtype: object
# power_kW      0.08272
# is_daytime       True
# Name: 2013-01-03 17:15:00, dtype: object
# power_kW      0.03985
# is_daytime       True
# Name: 2013-01-03 17:20:00, dtype: object
# power_kW      0.03585
# is_daytime       True
# Name: 2013-01-03 17:25:00, dtype: object
# power_kW      0.01033
# is_daytime       True
# Name: 2013-01-04 07:25:00, dtype: object
# power_kW      0.0168
# is_daytime      True
# Name: 2013-01-04 07:30:00, dtype: object
# power_kW      0.02533
# is_daytime       True
# Name: 2013-01-04 07:35:00, dtype: object
# power_kW      0.04635
# is_daytime       True
# Name: 2013-01-04 07:40:00, dtype: object
# power_kW      0.05912
# is_daytime       True
# Name: 2013-01-04 07:45:00, dtype: object
# power_kW      0.06806
# is_daytime       True
# Name: 2013-01-04 07:50:00, dtype: object
# power_kW      0.07189
# is_daytime       True
# Name: 2013-01-04 07:55:00, dtype: object
# power_kW      0.08037
# is_daytime       True
# Name: 2013-01-04 08:00:00, dtype: object
# power_kW      0.08152
# is_daytime       True
# Name: 2013-01-04 08:05:00, dtype: object
# power_kW      0.07822
# is_daytime       True
# Name: 2013-01-04 08:10:00, dtype: object
# power_kW      0.07709
# is_daytime       True
# Name: 2013-01-04 08:15:00, dtype: object
# power_kW      0.07518
# is_daytime       True
# Name: 2013-01-04 08:20:00, dtype: object
# power_kW      0.07658
# is_daytime       True
# Name: 2013-01-04 08:25:00, dtype: object
# power_kW      0.07751
# is_daytime       True
# Name: 2013-01-04 08:30:00, dtype: object
# power_kW      0.08
# is_daytime    True
# Name: 2013-01-04 08:35:00, dtype: object
# power_kW      0.08244
# is_daytime       True
# Name: 2013-01-04 08:40:00, dtype: object
# power_kW      0.09778
# is_daytime       True
# Name: 2013-01-04 08:45:00, dtype: object
# power_kW      0.13076
# is_daytime       True
# Name: 2013-01-04 08:50:00, dtype: object
# power_kW      0.13115
# is_daytime       True
# Name: 2013-01-04 08:55:00, dtype: object
# power_kW      0.12405
# is_daytime       True
# Name: 2013-01-04 09:00:00, dtype: object
# power_kW      0.11667
# is_daytime       True
# Name: 2013-01-04 09:05:00, dtype: object
# power_kW      0.11422
# is_daytime       True
# Name: 2013-01-04 09:10:00, dtype: object
# power_kW      0.12387
# is_daytime       True
# Name: 2013-01-04 09:15:00, dtype: object
# power_kW      0.13722
# is_daytime       True
# Name: 2013-01-04 09:20:00, dtype: object
# power_kW      0.1362
# is_daytime      True
# Name: 2013-01-04 09:25:00, dtype: object
# power_kW      0.14616
# is_daytime       True
# Name: 2013-01-04 09:30:00, dtype: object
# power_kW      0.16402
# is_daytime       True
# Name: 2013-01-04 09:35:00, dtype: object
# power_kW      0.18172
# is_daytime       True
# Name: 2013-01-04 09:40:00, dtype: object
# power_kW      0.21008
# is_daytime       True
# Name: 2013-01-04 09:45:00, dtype: object
# power_kW      0.24491
# is_daytime       True
# Name: 2013-01-04 09:50:00, dtype: object
# power_kW      0.26588
# is_daytime       True
# Name: 2013-01-04 09:55:00, dtype: object
# power_kW      0.30204
# is_daytime       True
# Name: 2013-01-04 10:00:00, dtype: object
# power_kW      0.35589
# is_daytime       True
# Name: 2013-01-04 10:05:00, dtype: object
# power_kW      0.39062
# is_daytime       True
# Name: 2013-01-04 10:10:00, dtype: object
# power_kW      0.45805
# is_daytime       True
# Name: 2013-01-04 10:15:00, dtype: object
# power_kW      0.37336
# is_daytime       True
# Name: 2013-01-04 10:20:00, dtype: object
# power_kW      0.33716
# is_daytime       True
# Name: 2013-01-04 10:25:00, dtype: object
# power_kW      0.31008
# is_daytime       True
# Name: 2013-01-04 10:30:00, dtype: object
# power_kW      0.29664
# is_daytime       True
# Name: 2013-01-04 10:35:00, dtype: object
# power_kW      0.29819
# is_daytime       True
# Name: 2013-01-04 10:40:00, dtype: object
# power_kW      0.30861
# is_daytime       True
# Name: 2013-01-04 10:45:00, dtype: object
# power_kW      0.3172
# is_daytime      True
# Name: 2013-01-04 10:50:00, dtype: object
# power_kW      0.36816
# is_daytime       True
# Name: 2013-01-04 10:55:00, dtype: object
# power_kW      0.34389
# is_daytime       True
# Name: 2013-01-04 11:00:00, dtype: object
# power_kW      0.44844
# is_daytime       True
# Name: 2013-01-04 11:05:00, dtype: object
# power_kW      0.67586
# is_daytime       True
# Name: 2013-01-04 11:10:00, dtype: object
# power_kW      0.65444
# is_daytime       True
# Name: 2013-01-04 11:15:00, dtype: object
# power_kW      0.60328
# is_daytime       True
# Name: 2013-01-04 11:20:00, dtype: object
# power_kW      0.67057
# is_daytime       True
# Name: 2013-01-04 11:25:00, dtype: object
# power_kW      0.57131
# is_daytime       True
# Name: 2013-01-04 11:30:00, dtype: object
# power_kW      0.67183
# is_daytime       True
# Name: 2013-01-04 11:35:00, dtype: object
# power_kW      0.70996
# is_daytime       True
# Name: 2013-01-04 11:40:00, dtype: object
# power_kW      0.65618
# is_daytime       True
# Name: 2013-01-04 11:45:00, dtype: object
# power_kW      0.74654
# is_daytime       True
# Name: 2013-01-04 11:50:00, dtype: object
# power_kW      0.69776
# is_daytime       True
# Name: 2013-01-04 11:55:00, dtype: object
# power_kW      0.41165
# is_daytime       True
# Name: 2013-01-04 12:00:00, dtype: object
# power_kW      0.29369
# is_daytime       True
# Name: 2013-01-04 12:05:00, dtype: object
# power_kW      0.29821
# is_daytime       True
# Name: 2013-01-04 12:10:00, dtype: object
# power_kW      0.36228
# is_daytime       True
# Name: 2013-01-04 12:15:00, dtype: object
# power_kW      0.42668
# is_daytime       True
# Name: 2013-01-04 12:20:00, dtype: object
# power_kW      0.56248
# is_daytime       True
# Name: 2013-01-04 12:25:00, dtype: object
# power_kW      0.59213
# is_daytime       True
# Name: 2013-01-04 12:30:00, dtype: object
# power_kW      0.64811
# is_daytime       True
# Name: 2013-01-04 12:35:00, dtype: object
# power_kW      0.57424
# is_daytime       True
# Name: 2013-01-04 12:40:00, dtype: object
# power_kW      0.50572
# is_daytime       True
# Name: 2013-01-04 12:45:00, dtype: object
# power_kW      0.51152
# is_daytime       True
# Name: 2013-01-04 12:50:00, dtype: object
# power_kW      0.57068
# is_daytime       True
# Name: 2013-01-04 12:55:00, dtype: object
# power_kW      0.55589
# is_daytime       True
# Name: 2013-01-04 13:00:00, dtype: object
# power_kW      0.57496
# is_daytime       True
# Name: 2013-01-04 13:05:00, dtype: object
# power_kW      0.44398
# is_daytime       True
# Name: 2013-01-04 13:10:00, dtype: object
# power_kW      0.50502
# is_daytime       True
# Name: 2013-01-04 13:15:00, dtype: object
# power_kW      0.52822
# is_daytime       True
# Name: 2013-01-04 13:20:00, dtype: object
# power_kW      0.37294
# is_daytime       True
# Name: 2013-01-04 13:25:00, dtype: object
# power_kW      0.34062
# is_daytime       True
# Name: 2013-01-04 13:30:00, dtype: object
# power_kW      0.34641
# is_daytime       True
# Name: 2013-01-04 13:35:00, dtype: object
# power_kW      0.35629
# is_daytime       True
# Name: 2013-01-04 13:40:00, dtype: object
# power_kW      0.40957
# is_daytime       True
# Name: 2013-01-04 13:45:00, dtype: object
# power_kW      0.40746
# is_daytime       True
# Name: 2013-01-04 13:50:00, dtype: object
# power_kW      0.43528
# is_daytime       True
# Name: 2013-01-04 13:55:00, dtype: object
# power_kW      0.399
# is_daytime     True
# Name: 2013-01-04 14:00:00, dtype: object
# power_kW      0.38929
# is_daytime       True
# Name: 2013-01-04 14:05:00, dtype: object
# power_kW      0.291968
# is_daytime        True
# Name: 2013-01-04 14:10:00, dtype: object
# power_kW      0.194645
# is_daytime        True
# Name: 2013-01-04 14:15:00, dtype: object
# power_kW      0.0973225
# is_daytime         True
# Name: 2013-01-04 14:20:00, dtype: object
# power_kW         0
# is_daytime    True
# Name: 2013-01-04 14:25:00, dtype: object
# power_kW      0.31089
# is_daytime       True
# Name: 2013-01-04 14:30:00, dtype: object
# power_kW      0.38244
# is_daytime       True
# Name: 2013-01-04 14:35:00, dtype: object
# power_kW      0.33346
# is_daytime       True
# Name: 2013-01-04 14:40:00, dtype: object
# power_kW      0.28918
# is_daytime       True
# Name: 2013-01-04 14:45:00, dtype: object
# power_kW      0.2746
# is_daytime      True
# Name: 2013-01-04 14:50:00, dtype: object
# power_kW      0.26869
# is_daytime       True
# Name: 2013-01-04 14:55:00, dtype: object
# power_kW      0.26852
# is_daytime       True
# Name: 2013-01-04 15:00:00, dtype: object
# power_kW      0.25704
# is_daytime       True
# Name: 2013-01-04 15:05:00, dtype: object
# power_kW      0.25954
# is_daytime       True
# Name: 2013-01-04 15:10:00, dtype: object
# power_kW      0.27786
# is_daytime       True
# Name: 2013-01-04 15:15:00, dtype: object
# power_kW      0.26406
# is_daytime       True
# Name: 2013-01-04 15:20:00, dtype: object
# power_kW      0.27792
# is_daytime       True
# Name: 2013-01-04 15:25:00, dtype: object
# power_kW      0.25707
# is_daytime       True
# Name: 2013-01-04 15:30:00, dtype: object
# power_kW      0.24257
# is_daytime       True
# Name: 2013-01-04 15:35:00, dtype: object
# power_kW      0.23441
# is_daytime       True
# Name: 2013-01-04 15:40:00, dtype: object
# power_kW      0.23671
# is_daytime       True
# Name: 2013-01-04 15:45:00, dtype: object
# power_kW      0.24153
# is_daytime       True
# Name: 2013-01-04 15:50:00, dtype: object
# power_kW      0.23445
# is_daytime       True
# Name: 2013-01-04 15:55:00, dtype: object
# power_kW      0.26215
# is_daytime       True
# Name: 2013-01-04 16:00:00, dtype: object
# power_kW      0.24571
# is_daytime       True
# Name: 2013-01-04 16:05:00, dtype: object
# power_kW      0.2584
# is_daytime      True
# Name: 2013-01-04 16:10:00, dtype: object
# power_kW      0.27407
# is_daytime       True
# Name: 2013-01-04 16:15:00, dtype: object
# power_kW      0.25938
# is_daytime       True
# Name: 2013-01-04 16:20:00, dtype: object
# power_kW      0.27261
# is_daytime       True
# Name: 2013-01-04 16:25:00, dtype: object
# power_kW      0.24086
# is_daytime       True
# Name: 2013-01-04 16:30:00, dtype: object
# power_kW      0.28466
# is_daytime       True
# Name: 2013-01-04 16:35:00, dtype: object
# power_kW      0.20593
# is_daytime       True
# Name: 2013-01-04 16:40:00, dtype: object
# power_kW      0.20811
# is_daytime       True
# Name: 2013-01-04 16:45:00, dtype: object
# power_kW      0.25623
# is_daytime       True
# Name: 2013-01-04 16:50:00, dtype: object
# power_kW      0.25944
# is_daytime       True
# Name: 2013-01-04 16:55:00, dtype: object
# power_kW      0.23364
# is_daytime       True
# Name: 2013-01-04 17:00:00, dtype: object
# power_kW      0.19525
# is_daytime       True
# Name: 2013-01-04 17:05:00, dtype: object
# power_kW      0.177
# is_daytime     True
# Name: 2013-01-04 17:10:00, dtype: object
# power_kW      0.14702
# is_daytime       True
# Name: 2013-01-04 17:15:00, dtype: object
# power_kW      0.07575
# is_daytime       True
# Name: 2013-01-04 17:20:00, dtype: object
# power_kW      0.01323
# is_daytime       True
# Name: 2013-01-05 07:10:00, dtype: object
# power_kW      0.03376
# is_daytime       True
# Name: 2013-01-05 07:15:00, dtype: object
# power_kW      0.04833
# is_daytime       True
# Name: 2013-01-05 07:20:00, dtype: object
# power_kW      0.05866
# is_daytime       True
# Name: 2013-01-05 07:25:00, dtype: object
# power_kW      0.06879
# is_daytime       True
# Name: 2013-01-05 07:30:00, dtype: object
# power_kW      0.07426
# is_daytime       True
# Name: 2013-01-05 07:35:00, dtype: object
# power_kW      0.08277
# is_daytime       True
# Name: 2013-01-05 07:40:00, dtype: object
# power_kW      0.07557
# is_daytime       True
# Name: 2013-01-05 07:45:00, dtype: object
# power_kW      0.0873
# is_daytime      True
# Name: 2013-01-05 07:50:00, dtype: object
# power_kW      0.10287
# is_daytime       True
# Name: 2013-01-05 07:55:00, dtype: object
# power_kW      0.11014
# is_daytime       True
# Name: 2013-01-05 08:00:00, dtype: object
# power_kW      0.12083
# is_daytime       True
# Name: 2013-01-05 08:05:00, dtype: object
# power_kW      0.14021
# is_daytime       True
# Name: 2013-01-05 08:10:00, dtype: object
# power_kW      0.15456
# is_daytime       True
# Name: 2013-01-05 08:15:00, dtype: object
# power_kW      0.15998
# is_daytime       True
# Name: 2013-01-05 08:20:00, dtype: object
# power_kW      0.16784
# is_daytime       True
# Name: 2013-01-05 08:25:00, dtype: object
# power_kW      0.17397
# is_daytime       True
# Name: 2013-01-05 08:30:00, dtype: object
# power_kW      0.18308
# is_daytime       True
# Name: 2013-01-05 08:35:00, dtype: object
# power_kW      0.21569
# is_daytime       True
# Name: 2013-01-05 08:40:00, dtype: object
# power_kW      0.24454
# is_daytime       True
# Name: 2013-01-05 08:45:00, dtype: object
# power_kW      0.26438
# is_daytime       True
# Name: 2013-01-05 08:50:00, dtype: object
# power_kW      0.28979
# is_daytime       True
# Name: 2013-01-05 08:55:00, dtype: object
# power_kW      0.29507
# is_daytime       True
# Name: 2013-01-05 09:00:00, dtype: object
# power_kW      0.31902
# is_daytime       True
# Name: 2013-01-05 09:05:00, dtype: object
# power_kW      0.35737
# is_daytime       True
# Name: 2013-01-05 09:10:00, dtype: object
# power_kW      0.38748
# is_daytime       True
# Name: 2013-01-05 09:15:00, dtype: object
# power_kW      0.41652
# is_daytime       True
# Name: 2013-01-05 09:20:00, dtype: object
# power_kW      0.44053
# is_daytime       True
# Name: 2013-01-05 09:25:00, dtype: object
# power_kW      0.45713
# is_daytime       True
# Name: 2013-01-05 09:30:00, dtype: object
# power_kW      0.43787
# is_daytime       True
# Name: 2013-01-05 09:35:00, dtype: object
# power_kW      0.48865
# is_daytime       True
# Name: 2013-01-05 09:40:00, dtype: object
# power_kW      0.533
# is_daytime     True
# Name: 2013-01-05 09:45:00, dtype: object
# power_kW      0.51549
# is_daytime       True
# Name: 2013-01-05 09:50:00, dtype: object
# power_kW      0.50683
# is_daytime       True
# Name: 2013-01-05 09:55:00, dtype: object
# power_kW      0.47061
# is_daytime       True
# Name: 2013-01-05 10:00:00, dtype: object
# power_kW      0.55042
# is_daytime       True
# Name: 2013-01-05 10:05:00, dtype: object
# power_kW      0.58042
# is_daytime       True
# Name: 2013-01-05 10:10:00, dtype: object
# power_kW      0.58705
# is_daytime       True
# Name: 2013-01-05 10:15:00, dtype: object
# power_kW      0.59948
# is_daytime       True
# Name: 2013-01-05 10:20:00, dtype: object
# power_kW      0.59798
# is_daytime       True
# Name: 2013-01-05 10:25:00, dtype: object
# power_kW      0.59851
# is_daytime       True
# Name: 2013-01-05 10:30:00, dtype: object
# power_kW      0.66926
# is_daytime       True
# Name: 2013-01-05 10:35:00, dtype: object
# power_kW      0.71124
# is_daytime       True
# Name: 2013-01-05 10:40:00, dtype: object
# power_kW      0.72957
# is_daytime       True
# Name: 2013-01-05 10:45:00, dtype: object
# power_kW      0.74718
# is_daytime       True
# Name: 2013-01-05 10:50:00, dtype: object
# power_kW      0.75677
# is_daytime       True
# Name: 2013-01-05 10:55:00, dtype: object
# power_kW      0.73422
# is_daytime       True
# Name: 2013-01-05 11:00:00, dtype: object
# power_kW      0.76223
# is_daytime       True
# Name: 2013-01-05 11:05:00, dtype: object
# power_kW      0.85572
# is_daytime       True
# Name: 2013-01-05 11:10:00, dtype: object
# power_kW      0.87112
# is_daytime       True
# Name: 2013-01-05 11:15:00, dtype: object
# power_kW      0.87738
# is_daytime       True
# Name: 2013-01-05 11:20:00, dtype: object
# power_kW      0.87892
# is_daytime       True
# Name: 2013-01-05 11:25:00, dtype: object
# power_kW      0.8737
# is_daytime      True
# Name: 2013-01-05 11:30:00, dtype: object
# power_kW      0.87698
# is_daytime       True
# Name: 2013-01-05 11:35:00, dtype: object
# power_kW      0.8282
# is_daytime      True
# Name: 2013-01-05 11:40:00, dtype: object
# power_kW      0.81761
# is_daytime       True
# Name: 2013-01-05 11:45:00, dtype: object
# power_kW      0.88177
# is_daytime       True
# Name: 2013-01-05 11:50:00, dtype: object
# power_kW      0.85839
# is_daytime       True
# Name: 2013-01-05 11:55:00, dtype: object
# power_kW      0.84516
# is_daytime       True
# Name: 2013-01-05 12:00:00, dtype: object
# power_kW      0.85935
# is_daytime       True
# Name: 2013-01-05 12:05:00, dtype: object
# power_kW      0.89074
# is_daytime       True
# Name: 2013-01-05 12:10:00, dtype: object
# power_kW      0.88794
# is_daytime       True
# Name: 2013-01-05 12:15:00, dtype: object
# power_kW      0.89542
# is_daytime       True
# Name: 2013-01-05 12:20:00, dtype: object
# power_kW      0.89859
# is_daytime       True
# Name: 2013-01-05 12:25:00, dtype: object
# power_kW      0.90723
# is_daytime       True
# Name: 2013-01-05 12:30:00, dtype: object
# power_kW      0.88588
# is_daytime       True
# Name: 2013-01-05 12:35:00, dtype: object
# power_kW      0.87124
# is_daytime       True
# Name: 2013-01-05 12:40:00, dtype: object
# power_kW      0.88561
# is_daytime       True
# Name: 2013-01-05 12:45:00, dtype: object
# power_kW      0.8692
# is_daytime      True
# Name: 2013-01-05 12:50:00, dtype: object
# power_kW      0.86291
# is_daytime       True
# Name: 2013-01-05 12:55:00, dtype: object
# power_kW      0.88982
# is_daytime       True
# Name: 2013-01-05 13:00:00, dtype: object
# power_kW      0.88426
# is_daytime       True
# Name: 2013-01-05 13:05:00, dtype: object
# power_kW      0.87502
# is_daytime       True
# Name: 2013-01-05 13:10:00, dtype: object
# power_kW      0.89044
# is_daytime       True
# Name: 2013-01-05 13:15:00, dtype: object
# power_kW      0.85405
# is_daytime       True
# Name: 2013-01-05 13:20:00, dtype: object
# power_kW      0.82584
# is_daytime       True
# Name: 2013-01-05 13:25:00, dtype: object
# power_kW      0.87553
# is_daytime       True
# Name: 2013-01-05 13:30:00, dtype: object
# power_kW      0.84909
# is_daytime       True
# Name: 2013-01-05 13:35:00, dtype: object
# power_kW      0.81541
# is_daytime       True
# Name: 2013-01-05 13:40:00, dtype: object
# power_kW      0.80214
# is_daytime       True
# Name: 2013-01-05 13:45:00, dtype: object
# power_kW      0.8137
# is_daytime      True
# Name: 2013-01-05 13:50:00, dtype: object
# power_kW      0.81572
# is_daytime       True
# Name: 2013-01-05 13:55:00, dtype: object
# power_kW      0.81891
# is_daytime       True
# Name: 2013-01-05 14:00:00, dtype: object
# power_kW      0.83213
# is_daytime       True
# Name: 2013-01-05 14:05:00, dtype: object
# power_kW      0.83345
# is_daytime       True
# Name: 2013-01-05 14:10:00, dtype: object
# power_kW      0.83393
# is_daytime       True
# Name: 2013-01-05 14:15:00, dtype: object
# ...
# is_daytime       True
# Name: 2013-04-26 07:55:00, dtype: object
# power_kW      0.281
# is_daytime     True
# Name: 2013-04-26 08:00:00, dtype: object
# power_kW      0.2965
# is_daytime      True
# Name: 2013-04-26 08:05:00, dtype: object
# power_kW      0.34278
# is_daytime       True
# Name: 2013-04-26 08:10:00, dtype: object
# power_kW      0.36982
# is_daytime       True
# Name: 2013-04-26 08:15:00, dtype: object
# power_kW      0.39692
# is_daytime       True
# Name: 2013-04-26 08:20:00, dtype: object
# power_kW      0.38725
# is_daytime       True
# Name: 2013-04-26 08:25:00, dtype: object
# power_kW      0.32636
# is_daytime       True
# Name: 2013-04-26 08:30:00, dtype: object
# power_kW      0.42896
# is_daytime       True
# Name: 2013-04-26 08:35:00, dtype: object
# power_kW      0.46415
# is_daytime       True
# Name: 2013-04-26 08:40:00, dtype: object
# power_kW      0.54608
# is_daytime       True
# Name: 2013-04-26 08:45:00, dtype: object
# power_kW      0.66139
# is_daytime       True
# Name: 2013-04-26 08:50:00, dtype: object
# power_kW      0.62341
# is_daytime       True
# Name: 2013-04-26 08:55:00, dtype: object
# power_kW      0.37805
# is_daytime       True
# Name: 2013-04-26 09:00:00, dtype: object
# power_kW      0.61842
# is_daytime       True
# Name: 2013-04-26 09:05:00, dtype: object
# power_kW      0.4367
# is_daytime      True
# Name: 2013-04-26 09:10:00, dtype: object
# power_kW      0.73998
# is_daytime       True
# Name: 2013-04-26 09:15:00, dtype: object
# power_kW      0.75296
# is_daytime       True
# Name: 2013-04-26 09:20:00, dtype: object
# power_kW      0.44415
# is_daytime       True
# Name: 2013-04-26 09:25:00, dtype: object
# power_kW      0.16331
# is_daytime       True
# Name: 2013-04-26 09:30:00, dtype: object
# power_kW      0.61909
# is_daytime       True
# Name: 2013-04-26 09:35:00, dtype: object
# power_kW      0.46525
# is_daytime       True
# Name: 2013-04-26 09:40:00, dtype: object
# power_kW      0.56367
# is_daytime       True
# Name: 2013-04-26 09:45:00, dtype: object
# power_kW      0.7326
# is_daytime      True
# Name: 2013-04-26 09:50:00, dtype: object
# power_kW      0.84344
# is_daytime       True
# Name: 2013-04-26 09:55:00, dtype: object
# power_kW      0.82405
# is_daytime       True
# Name: 2013-04-26 10:00:00, dtype: object
# power_kW      0.71389
# is_daytime       True
# Name: 2013-04-26 10:05:00, dtype: object
# power_kW      0.84883
# is_daytime       True
# Name: 2013-04-26 10:10:00, dtype: object
# power_kW      0.40047
# is_daytime       True
# Name: 2013-04-26 10:15:00, dtype: object
# power_kW      0.35824
# is_daytime       True
# Name: 2013-04-26 10:20:00, dtype: object
# power_kW      0.87238
# is_daytime       True
# Name: 2013-04-26 10:25:00, dtype: object
# power_kW      0.76075
# is_daytime       True
# Name: 2013-04-26 10:30:00, dtype: object
# power_kW      0.56471
# is_daytime       True
# Name: 2013-04-26 10:35:00, dtype: object
# power_kW      0.88039
# is_daytime       True
# Name: 2013-04-26 10:40:00, dtype: object
# power_kW      0.83518
# is_daytime       True
# Name: 2013-04-26 10:45:00, dtype: object
# power_kW      0.86939
# is_daytime       True
# Name: 2013-04-26 10:50:00, dtype: object
# power_kW      0.73635
# is_daytime       True
# Name: 2013-04-26 10:55:00, dtype: object
# power_kW      0.94956
# is_daytime       True
# Name: 2013-04-26 11:00:00, dtype: object
# power_kW      0.79045
# is_daytime       True
# Name: 2013-04-26 11:05:00, dtype: object
# power_kW      0.82015
# is_daytime       True
# Name: 2013-04-26 11:10:00, dtype: object
# power_kW      0.32877
# is_daytime       True
# Name: 2013-04-26 11:15:00, dtype: object
# power_kW      0.56664
# is_daytime       True
# Name: 2013-04-26 11:20:00, dtype: object
# power_kW      0.85196
# is_daytime       True
# Name: 2013-04-26 11:25:00, dtype: object
# power_kW      0.9557
# is_daytime      True
# Name: 2013-04-26 11:30:00, dtype: object
# power_kW      0.91282
# is_daytime       True
# Name: 2013-04-26 11:35:00, dtype: object
# power_kW      0.85865
# is_daytime       True
# Name: 2013-04-26 11:40:00, dtype: object
# power_kW      0.92424
# is_daytime       True
# Name: 2013-04-26 11:45:00, dtype: object
# power_kW      0.90529
# is_daytime       True
# Name: 2013-04-26 11:50:00, dtype: object
# power_kW      0.79268
# is_daytime       True
# Name: 2013-04-26 11:55:00, dtype: object
# power_kW      0.79754
# is_daytime       True
# Name: 2013-04-26 12:00:00, dtype: object
# power_kW      0.89305
# is_daytime       True
# Name: 2013-04-26 12:05:00, dtype: object
# power_kW      0.97393
# is_daytime       True
# Name: 2013-04-26 12:10:00, dtype: object
# power_kW      0.65849
# is_daytime       True
# Name: 2013-04-26 12:15:00, dtype: object
# power_kW      0.98185
# is_daytime       True
# Name: 2013-04-26 12:20:00, dtype: object
# power_kW      0.9875
# is_daytime      True
# Name: 2013-04-26 12:25:00, dtype: object
# power_kW      0.97823
# is_daytime       True
# Name: 2013-04-26 12:30:00, dtype: object
# power_kW      0.93552
# is_daytime       True
# Name: 2013-04-26 12:35:00, dtype: object
# power_kW      0.98707
# is_daytime       True
# Name: 2013-04-26 12:40:00, dtype: object
# power_kW      0.96625
# is_daytime       True
# Name: 2013-04-26 12:45:00, dtype: object
# power_kW      0.96085
# is_daytime       True
# Name: 2013-04-26 12:50:00, dtype: object
# power_kW      0.92589
# is_daytime       True
# Name: 2013-04-26 12:55:00, dtype: object
# power_kW      0.90073
# is_daytime       True
# Name: 2013-04-26 13:00:00, dtype: object
# power_kW      0.85513
# is_daytime       True
# Name: 2013-04-26 13:05:00, dtype: object
# power_kW      0.88576
# is_daytime       True
# Name: 2013-04-26 13:10:00, dtype: object
# power_kW      0.87868
# is_daytime       True
# Name: 2013-04-26 13:15:00, dtype: object
# power_kW      0.89986
# is_daytime       True
# Name: 2013-04-26 13:20:00, dtype: object
# power_kW      0.87676
# is_daytime       True
# Name: 2013-04-26 13:25:00, dtype: object
# power_kW      0.81585
# is_daytime       True
# Name: 2013-04-26 13:30:00, dtype: object
# power_kW      0.70585
# is_daytime       True
# Name: 2013-04-26 13:35:00, dtype: object
# power_kW      0.77524
# is_daytime       True
# Name: 2013-04-26 13:40:00, dtype: object
# power_kW      0.80509
# is_daytime       True
# Name: 2013-04-26 13:45:00, dtype: object
# power_kW      0.8463
# is_daytime      True
# Name: 2013-04-26 13:50:00, dtype: object
# power_kW      0.85402
# is_daytime       True
# Name: 2013-04-26 13:55:00, dtype: object
# power_kW      0.85975
# is_daytime       True
# Name: 2013-04-26 14:00:00, dtype: object
# power_kW      0.85373
# is_daytime       True
# Name: 2013-04-26 14:05:00, dtype: object
# power_kW      0.79938
# is_daytime       True
# Name: 2013-04-26 14:10:00, dtype: object
# power_kW      0.77316
# is_daytime       True
# Name: 2013-04-26 14:15:00, dtype: object
# power_kW      0.76761
# is_daytime       True
# Name: 2013-04-26 14:20:00, dtype: object
# power_kW      0.80578
# is_daytime       True
# Name: 2013-04-26 14:25:00, dtype: object
# power_kW      0.82006
# is_daytime       True
# Name: 2013-04-26 14:30:00, dtype: object
# power_kW      0.78787
# is_daytime       True
# Name: 2013-04-26 14:35:00, dtype: object
# power_kW      0.76811
# is_daytime       True
# Name: 2013-04-26 14:40:00, dtype: object
# power_kW      0.76696
# is_daytime       True
# Name: 2013-04-26 14:45:00, dtype: object
# power_kW      0.762
# is_daytime     True
# Name: 2013-04-26 14:50:00, dtype: object
# power_kW      0.74463
# is_daytime       True
# Name: 2013-04-26 14:55:00, dtype: object
# power_kW      0.73111
# is_daytime       True
# Name: 2013-04-26 15:00:00, dtype: object
# power_kW      0.71064
# is_daytime       True
# Name: 2013-04-26 15:05:00, dtype: object
# power_kW      0.65455
# is_daytime       True
# Name: 2013-04-26 15:10:00, dtype: object
# power_kW      0.68109
# is_daytime       True
# Name: 2013-04-26 15:15:00, dtype: object
# power_kW      0.65031
# is_daytime       True
# Name: 2013-04-26 15:20:00, dtype: object
# power_kW      0.64725
# is_daytime       True
# Name: 2013-04-26 15:25:00, dtype: object
# power_kW      0.63005
# is_daytime       True
# Name: 2013-04-26 15:30:00, dtype: object
# power_kW      0.61522
# is_daytime       True
# Name: 2013-04-26 15:35:00, dtype: object
# power_kW      0.6001
# is_daytime      True
# Name: 2013-04-26 15:40:00, dtype: object
# power_kW      0.57688
# is_daytime       True
# Name: 2013-04-26 15:45:00, dtype: object
# power_kW      0.55859
# is_daytime       True
# Name: 2013-04-26 15:50:00, dtype: object
# power_kW      0.54148
# is_daytime       True
# Name: 2013-04-26 15:55:00, dtype: object
# power_kW      0.51802
# is_daytime       True
# Name: 2013-04-26 16:00:00, dtype: object
# power_kW      0.50061
# is_daytime       True
# Name: 2013-04-26 16:05:00, dtype: object
# power_kW      0.47808
# is_daytime       True
# Name: 2013-04-26 16:10:00, dtype: object
# power_kW      0.45056
# is_daytime       True
# Name: 2013-04-26 16:15:00, dtype: object
# power_kW      0.41509
# is_daytime       True
# Name: 2013-04-26 16:20:00, dtype: object
# power_kW      0.40109
# is_daytime       True
# Name: 2013-04-26 16:25:00, dtype: object
# power_kW      0.38245
# is_daytime       True
# Name: 2013-04-26 16:30:00, dtype: object
# power_kW      0.363
# is_daytime     True
# Name: 2013-04-26 16:35:00, dtype: object
# power_kW      0.34631
# is_daytime       True
# Name: 2013-04-26 16:40:00, dtype: object
# power_kW      0.32148
# is_daytime       True
# Name: 2013-04-26 16:45:00, dtype: object
# power_kW      0.29465
# is_daytime       True
# Name: 2013-04-26 16:50:00, dtype: object
# power_kW      0.25232
# is_daytime       True
# Name: 2013-04-26 16:55:00, dtype: object
# power_kW      0.24058
# is_daytime       True
# Name: 2013-04-26 17:00:00, dtype: object
# power_kW      0.20398
# is_daytime       True
# Name: 2013-04-26 17:05:00, dtype: object
# power_kW      0.15818
# is_daytime       True
# Name: 2013-04-26 17:10:00, dtype: object
# power_kW      0.02089
# is_daytime       True
# Name: 2013-04-27 07:20:00, dtype: object
# power_kW      0.03176
# is_daytime       True
# Name: 2013-04-27 07:25:00, dtype: object
# power_kW      0.03698
# is_daytime       True
# Name: 2013-04-27 07:30:00, dtype: object
# power_kW      0.037
# is_daytime     True
# Name: 2013-04-27 07:35:00, dtype: object
# power_kW      0.05863
# is_daytime       True
# Name: 2013-04-27 07:40:00, dtype: object
# power_kW      0.06433
# is_daytime       True
# Name: 2013-04-27 07:45:00, dtype: object
# power_kW      0.0846
# is_daytime      True
# Name: 2013-04-27 07:50:00, dtype: object
# power_kW      0.08181
# is_daytime       True
# Name: 2013-04-27 07:55:00, dtype: object
# power_kW      0.10445
# is_daytime       True
# Name: 2013-04-27 08:00:00, dtype: object
# power_kW      0.11835
# is_daytime       True
# Name: 2013-04-27 08:05:00, dtype: object
# power_kW      0.13473
# is_daytime       True
# Name: 2013-04-27 08:10:00, dtype: object
# power_kW      0.15335
# is_daytime       True
# Name: 2013-04-27 08:15:00, dtype: object
# power_kW      0.15563
# is_daytime       True
# Name: 2013-04-27 08:20:00, dtype: object
# power_kW      0.15631
# is_daytime       True
# Name: 2013-04-27 08:25:00, dtype: object
# power_kW      0.15761
# is_daytime       True
# Name: 2013-04-27 08:30:00, dtype: object
# power_kW      0.15529
# is_daytime       True
# Name: 2013-04-27 08:35:00, dtype: object
# power_kW      0.21945
# is_daytime       True
# Name: 2013-04-27 08:40:00, dtype: object
# power_kW      0.21807
# is_daytime       True
# Name: 2013-04-27 08:45:00, dtype: object
# power_kW      0.25133
# is_daytime       True
# Name: 2013-04-27 08:50:00, dtype: object
# power_kW      0.2565
# is_daytime      True
# Name: 2013-04-27 08:55:00, dtype: object
# power_kW      0.30555
# is_daytime       True
# Name: 2013-04-27 09:00:00, dtype: object
# power_kW      0.33853
# is_daytime       True
# Name: 2013-04-27 09:05:00, dtype: object
# power_kW      0.37236
# is_daytime       True
# Name: 2013-04-27 09:10:00, dtype: object
# power_kW      0.387
# is_daytime     True
# Name: 2013-04-27 09:15:00, dtype: object
# power_kW      0.3948
# is_daytime      True
# Name: 2013-04-27 09:20:00, dtype: object
# power_kW      0.30507
# is_daytime       True
# Name: 2013-04-27 09:25:00, dtype: object
# power_kW      0.30439
# is_daytime       True
# Name: 2013-04-27 09:30:00, dtype: object
# power_kW      0.40977
# is_daytime       True
# Name: 2013-04-27 09:35:00, dtype: object
# power_kW      0.57567
# is_daytime       True
# Name: 2013-04-27 09:40:00, dtype: object
# power_kW      0.82159
# is_daytime       True
# Name: 2013-04-27 09:45:00, dtype: object
# power_kW      0.668
# is_daytime     True
# Name: 2013-04-27 09:50:00, dtype: object
# power_kW      0.53738
# is_daytime       True
# Name: 2013-04-27 09:55:00, dtype: object
# power_kW      0.41721
# is_daytime       True
# Name: 2013-04-27 10:00:00, dtype: object
# power_kW      0.4948
# is_daytime      True
# Name: 2013-04-27 10:05:00, dtype: object
# power_kW      0.48106
# is_daytime       True
# Name: 2013-04-27 10:10:00, dtype: object
# power_kW      0.24742
# is_daytime       True
# Name: 2013-04-27 10:15:00, dtype: object
# power_kW      0.6911
# is_daytime      True
# Name: 2013-04-27 10:20:00, dtype: object
# power_kW      0.84555
# is_daytime       True
# Name: 2013-04-27 10:25:00, dtype: object
# power_kW      0.85752
# is_daytime       True
# Name: 2013-04-27 10:30:00, dtype: object
# power_kW      0.35805
# is_daytime       True
# Name: 2013-04-27 10:35:00, dtype: object
# power_kW      0.71988
# is_daytime       True
# Name: 2013-04-27 10:40:00, dtype: object
# power_kW      0.5554
# is_daytime      True
# Name: 2013-04-27 10:45:00, dtype: object
# power_kW      0.52411
# is_daytime       True
# Name: 2013-04-27 10:50:00, dtype: object
# power_kW      0.65313
# is_daytime       True
# Name: 2013-04-27 10:55:00, dtype: object
# power_kW      0.61305
# is_daytime       True
# Name: 2013-04-27 11:00:00, dtype: object
# power_kW      0.6146
# is_daytime      True
# Name: 2013-04-27 11:05:00, dtype: object
# power_kW      0.3755
# is_daytime      True
# Name: 2013-04-27 11:10:00, dtype: object
# power_kW      0.94457
# is_daytime       True
# Name: 2013-04-27 11:15:00, dtype: object
# power_kW      0.92294
# is_daytime       True
# Name: 2013-04-27 11:20:00, dtype: object
# power_kW      0.641
# is_daytime     True
# Name: 2013-04-27 11:25:00, dtype: object
# power_kW      0.3778
# is_daytime      True
# Name: 2013-04-27 11:30:00, dtype: object
# power_kW      0.31764
# is_daytime       True
# Name: 2013-04-27 11:35:00, dtype: object
# power_kW      0.19059
# is_daytime       True
# Name: 2013-04-27 11:40:00, dtype: object
# power_kW      0.35207
# is_daytime       True
# Name: 2013-04-27 11:45:00, dtype: object
# power_kW      0.21595
# is_daytime       True
# Name: 2013-04-27 11:50:00, dtype: object
# power_kW      0.74127
# is_daytime       True
# Name: 2013-04-27 11:55:00, dtype: object
# power_kW      0.91728
# is_daytime       True
# Name: 2013-04-27 12:00:00, dtype: object
# power_kW      0.69865
# is_daytime       True
# Name: 2013-04-27 12:05:00, dtype: object
# power_kW      0.61482
# is_daytime       True
# Name: 2013-04-27 12:10:00, dtype: object
# power_kW      0.69544
# is_daytime       True
# Name: 2013-04-27 12:15:00, dtype: object
# power_kW      0.91895
# is_daytime       True
# Name: 2013-04-27 12:20:00, dtype: object
# power_kW      0.93231
# is_daytime       True
# Name: 2013-04-27 12:25:00, dtype: object
# power_kW      0.5025
# is_daytime      True
# Name: 2013-04-27 12:30:00, dtype: object
# power_kW      0.92649
# is_daytime       True
# Name: 2013-04-27 12:35:00, dtype: object
# power_kW      0.92565
# is_daytime       True
# Name: 2013-04-27 12:40:00, dtype: object
# power_kW      0.91898
# is_daytime       True
# Name: 2013-04-27 12:45:00, dtype: object
# power_kW      0.89613
# is_daytime       True
# Name: 2013-04-27 12:50:00, dtype: object
# power_kW      0.88845
# is_daytime       True
# Name: 2013-04-27 12:55:00, dtype: object
# power_kW      0.92875
# is_daytime       True
# Name: 2013-04-27 13:00:00, dtype: object
# power_kW      0.90984
# is_daytime       True
# Name: 2013-04-27 13:05:00, dtype: object
# power_kW      0.88876
# is_daytime       True
# Name: 2013-04-27 13:10:00, dtype: object
# power_kW      0.90455
# is_daytime       True
# Name: 2013-04-27 13:15:00, dtype: object
# power_kW      0.81153
# is_daytime       True
# Name: 2013-04-27 13:20:00, dtype: object
# power_kW      0.8926
# is_daytime      True
# Name: 2013-04-27 13:25:00, dtype: object
# power_kW      0.88861
# is_daytime       True
# Name: 2013-04-27 13:30:00, dtype: object
# power_kW      0.88818
# is_daytime       True
# Name: 2013-04-27 13:35:00, dtype: object
# power_kW      0.86515
# is_daytime       True
# Name: 2013-04-27 13:40:00, dtype: object

# %%
data_daytime.iloc[:150,:].plot(y=['power_kW'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-afa0fc7c4747> in <module>()
# ----> 1 data_daytime.iloc[:150,:].plot(y=['power_kW'])
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1855                  yerr=yerr, xerr=xerr,
#    1856                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1857                  **kwds)
#    1858
#    1859
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1680         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1681
# -> 1682     plot_obj.generate()
#    1683     plot_obj.draw()
#    1684     return plot_obj.result
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     234     def generate(self):
#     235         self._args_adjust()
# --> 236         self._compute_plot_data()
#     237         self._setup_subplots()
#     238         self._make_plot()
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     343         if is_empty:
#     344             raise TypeError('Empty {0!r}: no numeric data to '
# --> 345                             'plot'.format(numeric_data.__class__.__name__))
#     346
#     347         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
